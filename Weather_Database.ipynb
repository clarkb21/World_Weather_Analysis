# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
from citipy import citipy

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes. This also helps stay under the 60 API calls per minute limit
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]['description']
        city_country = city_weather['sys']['country']
        
         # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country" : city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except KeyError:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vardo
# Processing Record 2 of Set 1 | inhambane
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | kavieng
# Processing Record 5 of Set 1 | nishihara
# Processing Record 6 of Set 1 | cherskiy
# Processing Record 7 of Set 1 | bethel
# Processing Record 8 of Set 1 | dikson
# Processing Record 9 of Set 1 | buala
# Processing Record 10 of Set 1 | leh
# Processing Record 11 of Set 1 | tarko-sale
# Processing Record 12 of Set 1 | grindavik
# Processing Record 13 of Set 1 | floro
# Processing Record 14 of Set 1 | thanh hoa
# Processing Record 15 of Set 1 | bulnes
# Processing Record 16 of Set 1 | east london
# Processing Record 17 of Set 1 | solnechnyy
# Processing Record 18 of Set 1 | kodiak
# Processing Record 19 of Set 1 | hobart
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | gurgan
# City not found. Skipping...
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | haines junction
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | saint anthony
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | butaritari
# Processing Record 29 of Set 1 | jamestown
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | bac lieu
# Processing Record 33 of Set 1 | yaan
# Processing Record 34 of Set 1 | ust-tsilma
# Processing Record 35 of Set 1 | lorengau
# Processing Record 36 of Set 1 | bonavista
# Processing Record 37 of Set 1 | ushuaia
# Processing Record 38 of Set 1 | richards bay
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | bengkulu
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | burica
# City not found. Skipping...
# Processing Record 43 of Set 1 | paamiut
# Processing Record 44 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | geraldton
# Processing Record 47 of Set 1 | hermanus
# Processing Record 48 of Set 1 | faanui
# Processing Record 49 of Set 1 | mar del plata
# Processing Record 50 of Set 1 | mana
# Processing Record 1 of Set 2 | thinadhoo
# Processing Record 2 of Set 2 | cabedelo
# Processing Record 3 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 2 | luderitz
# Processing Record 5 of Set 2 | tarbagatay
# Processing Record 6 of Set 2 | tiksi
# Processing Record 7 of Set 2 | sitka
# Processing Record 8 of Set 2 | port lincoln
# Processing Record 9 of Set 2 | matara
# Processing Record 10 of Set 2 | tombouctou
# Processing Record 11 of Set 2 | maltahohe
# Processing Record 12 of Set 2 | zabid
# Processing Record 13 of Set 2 | rawlins
# Processing Record 14 of Set 2 | maragogi
# Processing Record 15 of Set 2 | victoria
# Processing Record 16 of Set 2 | manokwari
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | saint-philippe
# Processing Record 19 of Set 2 | dire dawa
# Processing Record 20 of Set 2 | coahuayana
# Processing Record 21 of Set 2 | bambous virieux
# Processing Record 22 of Set 2 | kapaa
# Processing Record 23 of Set 2 | bandarbeyla
# Processing Record 24 of Set 2 | touros
# Processing Record 25 of Set 2 | karamea
# City not found. Skipping...
# Processing Record 26 of Set 2 | dargaville
# Processing Record 27 of Set 2 | puerto del rosario
# Processing Record 28 of Set 2 | tilichiki
# Processing Record 29 of Set 2 | xai-xai
# Processing Record 30 of Set 2 | pevek
# Processing Record 31 of Set 2 | saravan
# Processing Record 32 of Set 2 | clyde river
# Processing Record 33 of Set 2 | upata
# Processing Record 34 of Set 2 | teruel
# Processing Record 35 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 36 of Set 2 | nikolskoye
# Processing Record 37 of Set 2 | majenang
# Processing Record 38 of Set 2 | tripoli
# Processing Record 39 of Set 2 | denpasar
# Processing Record 40 of Set 2 | barentu
# Processing Record 41 of Set 2 | gwadar
# Processing Record 42 of Set 2 | antibes
# Processing Record 43 of Set 2 | bilibino
# Processing Record 44 of Set 2 | opuwo
# Processing Record 45 of Set 2 | ngorongoro
# Processing Record 46 of Set 2 | tuatapere
# Processing Record 47 of Set 2 | stepnyak
# Processing Record 48 of Set 2 | ovalle
# Processing Record 49 of Set 2 | navolato
# Processing Record 50 of Set 2 | thompson
# Processing Record 1 of Set 3 | wanning
# Processing Record 2 of Set 3 | husavik
# Processing Record 3 of Set 3 | cascais
# Processing Record 4 of Set 3 | viedma
# Processing Record 5 of Set 3 | santa cruz de tenerife
# Processing Record 6 of Set 3 | yellowknife
# Processing Record 7 of Set 3 | broome
# Processing Record 8 of Set 3 | chuy
# Processing Record 9 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 3 | itoman
# Processing Record 11 of Set 3 | emerald
# Processing Record 12 of Set 3 | evensk
# Processing Record 13 of Set 3 | labuhan
# Processing Record 14 of Set 3 | hithadhoo
# Processing Record 15 of Set 3 | iqaluit
# Processing Record 16 of Set 3 | seoul
# Processing Record 17 of Set 3 | qui nhon
# Processing Record 18 of Set 3 | kudahuvadhoo
# Processing Record 19 of Set 3 | namibe
# Processing Record 20 of Set 3 | siguiri
# Processing Record 21 of Set 3 | sao paulo de olivenca
# Processing Record 22 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 3 | westport
# Processing Record 24 of Set 3 | nicoya
# Processing Record 25 of Set 3 | hambantota
# Processing Record 26 of Set 3 | kruisfontein
# Processing Record 27 of Set 3 | mulege
# Processing Record 28 of Set 3 | castro
# Processing Record 29 of Set 3 | kallithea
# Processing Record 30 of Set 3 | bluff
# Processing Record 31 of Set 3 | ucluelet
# Processing Record 32 of Set 3 | arraial do cabo
# Processing Record 33 of Set 3 | kikwit
# Processing Record 34 of Set 3 | santo antonio do ica
# Processing Record 35 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 3 | tuktoyaktuk
# Processing Record 37 of Set 3 | bredasdorp
# Processing Record 38 of Set 3 | foz
# Processing Record 39 of Set 3 | mount gambier
# Processing Record 40 of Set 3 | mutoko
# Processing Record 41 of Set 3 | mahebourg
# Processing Record 42 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 3 | daxian
# City not found. Skipping...
# Processing Record 44 of Set 3 | puerto ayora
# Processing Record 45 of Set 3 | bell ville
# Processing Record 46 of Set 3 | darhan
# Processing Record 47 of Set 3 | aklavik
# Processing Record 48 of Set 3 | saint george
# Processing Record 49 of Set 3 | agrado
# Processing Record 50 of Set 3 | los llanos de aridane
# Processing Record 1 of Set 4 | new norfolk
# Processing Record 2 of Set 4 | airai
# Processing Record 3 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 4 | san jeronimo
# Processing Record 5 of Set 4 | mayo
# Processing Record 6 of Set 4 | naze
# Processing Record 7 of Set 4 | mozarlandia
# Processing Record 8 of Set 4 | upernavik
# Processing Record 9 of Set 4 | cockburn town
# Processing Record 10 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 4 | piedra gorda
# Processing Record 12 of Set 4 | xinzhi
# Processing Record 13 of Set 4 | alice springs
# Processing Record 14 of Set 4 | port elizabeth
# Processing Record 15 of Set 4 | neyshabur
# Processing Record 16 of Set 4 | hurghada
# Processing Record 17 of Set 4 | kaitangata
# Processing Record 18 of Set 4 | tabou
# Processing Record 19 of Set 4 | manuk mangkaw
# Processing Record 20 of Set 4 | isangel
# Processing Record 21 of Set 4 | alikalia
# Processing Record 22 of Set 4 | rudbar
# Processing Record 23 of Set 4 | cabo san lucas
# Processing Record 24 of Set 4 | sijunjung
# Processing Record 25 of Set 4 | oranjemund
# Processing Record 26 of Set 4 | letka
# Processing Record 27 of Set 4 | saint-georges
# Processing Record 28 of Set 4 | srednekolymsk
# Processing Record 29 of Set 4 | lavrentiya
# Processing Record 30 of Set 4 | hamilton
# Processing Record 31 of Set 4 | soubre
# Processing Record 32 of Set 4 | marsh harbour
# Processing Record 33 of Set 4 | baherden
# Processing Record 34 of Set 4 | ewa beach
# Processing Record 35 of Set 4 | leningradskiy
# Processing Record 36 of Set 4 | tazovskiy
# Processing Record 37 of Set 4 | nsukka
# Processing Record 38 of Set 4 | faya
# Processing Record 39 of Set 4 | beruwala
# Processing Record 40 of Set 4 | carnarvon
# Processing Record 41 of Set 4 | hamburg
# Processing Record 42 of Set 4 | kozhva
# Processing Record 43 of Set 4 | khatanga
# Processing Record 44 of Set 4 | eregli
# Processing Record 45 of Set 4 | yerbogachen
# Processing Record 46 of Set 4 | concordia
# Processing Record 47 of Set 4 | samarai
# Processing Record 48 of Set 4 | torbay
# Processing Record 49 of Set 4 | high prairie
# Processing Record 50 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 1 of Set 5 | caapucu
# Processing Record 2 of Set 5 | limulunga
# Processing Record 3 of Set 5 | lebu
# Processing Record 4 of Set 5 | botwood
# Processing Record 5 of Set 5 | poronaysk
# Processing Record 6 of Set 5 | shache
# Processing Record 7 of Set 5 | klaksvik
# Processing Record 8 of Set 5 | havoysund
# Processing Record 9 of Set 5 | westpunt
# City not found. Skipping...
# Processing Record 10 of Set 5 | rio grande
# Processing Record 11 of Set 5 | tasiilaq
# Processing Record 12 of Set 5 | barrow
# Processing Record 13 of Set 5 | fort nelson
# Processing Record 14 of Set 5 | santa vitoria do palmar
# Processing Record 15 of Set 5 | kavaratti
# Processing Record 16 of Set 5 | ilulissat
# Processing Record 17 of Set 5 | zeya
# Processing Record 18 of Set 5 | lagoa
# Processing Record 19 of Set 5 | yeppoon
# Processing Record 20 of Set 5 | esperance
# Processing Record 21 of Set 5 | aguimes
# Processing Record 22 of Set 5 | katsiveli
# City not found. Skipping...
# Processing Record 23 of Set 5 | georgetown
# Processing Record 24 of Set 5 | aleksandrov gay
# Processing Record 25 of Set 5 | marsala
# Processing Record 26 of Set 5 | kahului
# Processing Record 27 of Set 5 | kargasok
# Processing Record 28 of Set 5 | bayonet point
# Processing Record 29 of Set 5 | port hardy
# Processing Record 30 of Set 5 | constitucion
# Processing Record 31 of Set 5 | lumberton
# Processing Record 32 of Set 5 | abu dhabi
# Processing Record 33 of Set 5 | roald
# Processing Record 34 of Set 5 | deshna
# City not found. Skipping...
# Processing Record 35 of Set 5 | bambanglipuro
# Processing Record 36 of Set 5 | keti bandar
# Processing Record 37 of Set 5 | mehamn
# Processing Record 38 of Set 5 | sandanski
# Processing Record 39 of Set 5 | loja
# Processing Record 40 of Set 5 | popondetta
# Processing Record 41 of Set 5 | launceston
# Processing Record 42 of Set 5 | falealupo
# City not found. Skipping...
# Processing Record 43 of Set 5 | xapuri
# Processing Record 44 of Set 5 | san isidro
# Processing Record 45 of Set 5 | boda
# Processing Record 46 of Set 5 | tautira
# Processing Record 47 of Set 5 | chalmette
# Processing Record 48 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 5 | kisangani
# Processing Record 50 of Set 5 | saint-pierre
# Processing Record 1 of Set 6 | kenora
# Processing Record 2 of Set 6 | yebaishou
# Processing Record 3 of Set 6 | turtkul
# City not found. Skipping...
# Processing Record 4 of Set 6 | ostrovnoy
# Processing Record 5 of Set 6 | tabora
# Processing Record 6 of Set 6 | lubango
# Processing Record 7 of Set 6 | san carlos de bariloche
# Processing Record 8 of Set 6 | warrensburg
# Processing Record 9 of Set 6 | te anau
# Processing Record 10 of Set 6 | alyangula
# Processing Record 11 of Set 6 | menongue
# Processing Record 12 of Set 6 | gillette
# Processing Record 13 of Set 6 | longyearbyen
# Processing Record 14 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 15 of Set 6 | biak
# Processing Record 16 of Set 6 | matelica
# Processing Record 17 of Set 6 | ilabaya
# Processing Record 18 of Set 6 | saskylakh
# Processing Record 19 of Set 6 | zhuanghe
# Processing Record 20 of Set 6 | shingu
# Processing Record 21 of Set 6 | narsaq
# Processing Record 22 of Set 6 | ayan
# Processing Record 23 of Set 6 | talnakh
# Processing Record 24 of Set 6 | ullapool
# Processing Record 25 of Set 6 | mizdah
# Processing Record 26 of Set 6 | saint-leu
# Processing Record 27 of Set 6 | sakakah
# Processing Record 28 of Set 6 | udalguri
# Processing Record 29 of Set 6 | chokurdakh
# Processing Record 30 of Set 6 | el playon
# Processing Record 31 of Set 6 | flinders
# Processing Record 32 of Set 6 | provideniya
# Processing Record 33 of Set 6 | ust-nera
# Processing Record 34 of Set 6 | nanortalik
# Processing Record 35 of Set 6 | marugame
# Processing Record 36 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 38 of Set 6 | vanavara
# Processing Record 39 of Set 6 | karratha
# Processing Record 40 of Set 6 | saint-joseph
# Processing Record 41 of Set 6 | nipawin
# Processing Record 42 of Set 6 | jiangyou
# Processing Record 43 of Set 6 | meulaboh
# Processing Record 44 of Set 6 | chernyshevskiy
# Processing Record 45 of Set 6 | saint-louis
# Processing Record 46 of Set 6 | carutapera
# Processing Record 47 of Set 6 | halifax
# Processing Record 48 of Set 6 | karachi
# Processing Record 49 of Set 6 | batagay-alyta
# Processing Record 50 of Set 6 | kangaatsiaq
# Processing Record 1 of Set 7 | kuybyshevo
# Processing Record 2 of Set 7 | boguchany
# Processing Record 3 of Set 7 | broken hill
# Processing Record 4 of Set 7 | kashi
# Processing Record 5 of Set 7 | kununurra
# Processing Record 6 of Set 7 | port-gentil
# Processing Record 7 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 8 of Set 7 | college
# Processing Record 9 of Set 7 | colares
# Processing Record 10 of Set 7 | pak phanang
# Processing Record 11 of Set 7 | berlevag
# Processing Record 12 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 7 | hellvik
# Processing Record 14 of Set 7 | moissala
# Processing Record 15 of Set 7 | ponta do sol
# Processing Record 16 of Set 7 | baykit
# Processing Record 17 of Set 7 | oranjestad
# Processing Record 18 of Set 7 | tungor
# Processing Record 19 of Set 7 | ushumun
# Processing Record 20 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 7 | zholymbet
# Processing Record 22 of Set 7 | manoel urbano
# Processing Record 23 of Set 7 | sao filipe
# Processing Record 24 of Set 7 | srandakan
# Processing Record 25 of Set 7 | hofn
# Processing Record 26 of Set 7 | kamaishi
# Processing Record 27 of Set 7 | tsumeb
# Processing Record 28 of Set 7 | plettenberg bay
# Processing Record 29 of Set 7 | trimbak
# Processing Record 30 of Set 7 | price
# Processing Record 31 of Set 7 | jizan
# Processing Record 32 of Set 7 | nome
# Processing Record 33 of Set 7 | guerrero negro
# Processing Record 34 of Set 7 | lethem
# Processing Record 35 of Set 7 | saldanha
# Processing Record 36 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 7 | olafsvik
# Processing Record 38 of Set 7 | tayshet
# Processing Record 39 of Set 7 | durant
# Processing Record 40 of Set 7 | kautokeino
# Processing Record 41 of Set 7 | takoradi
# Processing Record 42 of Set 7 | puerto gaitan
# Processing Record 43 of Set 7 | chernaya kholunitsa
# Processing Record 44 of Set 7 | uniao da victoria
# City not found. Skipping...
# Processing Record 45 of Set 7 | little current
# Processing Record 46 of Set 7 | palauig
# Processing Record 47 of Set 7 | elverum
# Processing Record 48 of Set 7 | benito juarez
# Processing Record 49 of Set 7 | bubaque
# Processing Record 50 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 8 | ciempozuelos
# Processing Record 2 of Set 8 | vengerovo
# Processing Record 3 of Set 8 | savannakhet
# Processing Record 4 of Set 8 | fortuna
# Processing Record 5 of Set 8 | jutai
# Processing Record 6 of Set 8 | carauari
# Processing Record 7 of Set 8 | hay river
# Processing Record 8 of Set 8 | san cristobal
# Processing Record 9 of Set 8 | amapa
# Processing Record 10 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 8 | prince george
# Processing Record 12 of Set 8 | pajan
# Processing Record 13 of Set 8 | coquimbo
# Processing Record 14 of Set 8 | kamennomostskoye
# Processing Record 15 of Set 8 | udachnyy
# Processing Record 16 of Set 8 | chinsali
# Processing Record 17 of Set 8 | hudiksvall
# Processing Record 18 of Set 8 | vaitape
# Processing Record 19 of Set 8 | dicabisagan
# Processing Record 20 of Set 8 | carndonagh
# Processing Record 21 of Set 8 | itaituba
# Processing Record 22 of Set 8 | praia da vitoria
# Processing Record 23 of Set 8 | wahran
# City not found. Skipping...
# Processing Record 24 of Set 8 | wagar
# Processing Record 25 of Set 8 | port moresby
# Processing Record 26 of Set 8 | monrovia
# Processing Record 27 of Set 8 | marsa matruh
# Processing Record 28 of Set 8 | viytivka
# Processing Record 29 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 30 of Set 8 | taltal
# Processing Record 31 of Set 8 | senges
# Processing Record 32 of Set 8 | xinzhou
# Processing Record 33 of Set 8 | logansport
# Processing Record 34 of Set 8 | leiyang
# Processing Record 35 of Set 8 | alihe
# Processing Record 36 of Set 8 | sarakhs
# Processing Record 37 of Set 8 | juneau
# Processing Record 38 of Set 8 | vao
# Processing Record 39 of Set 8 | veraval
# Processing Record 40 of Set 8 | igatpuri
# Processing Record 41 of Set 8 | saint-augustin
# Processing Record 42 of Set 8 | pisco
# Processing Record 43 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 8 | tahta
# Processing Record 45 of Set 8 | leeston
# Processing Record 46 of Set 8 | ribeira grande
# Processing Record 47 of Set 8 | tabas
# Processing Record 48 of Set 8 | karakol
# Processing Record 49 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 8 | vila franca do campo
# Processing Record 1 of Set 9 | luanda
# Processing Record 2 of Set 9 | muravlenko
# Processing Record 3 of Set 9 | quatre cocos
# Processing Record 4 of Set 9 | irbit
# Processing Record 5 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 9 | ensley
# Processing Record 7 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 8 of Set 9 | qaqortoq
# Processing Record 9 of Set 9 | port blair
# Processing Record 10 of Set 9 | coihaique
# Processing Record 11 of Set 9 | muriti
# Processing Record 12 of Set 9 | salalah
# Processing Record 13 of Set 9 | jalu
# Processing Record 14 of Set 9 | florianopolis
# Processing Record 15 of Set 9 | itarema
# Processing Record 16 of Set 9 | lompoc
# Processing Record 17 of Set 9 | avera
# Processing Record 18 of Set 9 | young
# Processing Record 19 of Set 9 | montrose
# Processing Record 20 of Set 9 | pakxan
# Processing Record 21 of Set 9 | keuruu
# Processing Record 22 of Set 9 | tiruchchendur
# Processing Record 23 of Set 9 | norman wells
# Processing Record 24 of Set 9 | sao francisco
# Processing Record 25 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 26 of Set 9 | moindou
# Processing Record 27 of Set 9 | flin flon
# Processing Record 28 of Set 9 | dingle
# Processing Record 29 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 9 | northam
# Processing Record 31 of Set 9 | belyy yar
# Processing Record 32 of Set 9 | saeby
# Processing Record 33 of Set 9 | souillac
# Processing Record 34 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 9 | tura
# Processing Record 36 of Set 9 | fairbanks
# Processing Record 37 of Set 9 | goderich
# Processing Record 38 of Set 9 | codrington
# Processing Record 39 of Set 9 | xining
# Processing Record 40 of Set 9 | maracaibo
# Processing Record 41 of Set 9 | puerto leguizamo
# Processing Record 42 of Set 9 | oudtshoorn
# Processing Record 43 of Set 9 | le mars
# Processing Record 44 of Set 9 | la ronge
# Processing Record 45 of Set 9 | silver city
# Processing Record 46 of Set 9 | shuyskoye
# Processing Record 47 of Set 9 | joensuu
# Processing Record 48 of Set 9 | kampot
# Processing Record 49 of Set 9 | san patricio
# Processing Record 50 of Set 9 | lebanon
# Processing Record 1 of Set 10 | partizanskoye
# Processing Record 2 of Set 10 | pabrade
# Processing Record 3 of Set 10 | nguruka
# Processing Record 4 of Set 10 | kedrovyy
# Processing Record 5 of Set 10 | dunedin
# Processing Record 6 of Set 10 | katsuura
# Processing Record 7 of Set 10 | kamloops
# Processing Record 8 of Set 10 | simbahan
# Processing Record 9 of Set 10 | presidente epitacio
# Processing Record 10 of Set 10 | nioro
# Processing Record 11 of Set 10 | mazara del vallo
# Processing Record 12 of Set 10 | san francisco
# Processing Record 13 of Set 10 | wageningen
# Processing Record 14 of Set 10 | ahipara
# Processing Record 15 of Set 10 | daru
# Processing Record 16 of Set 10 | muriwai beach
# Processing Record 17 of Set 10 | la sarre
# Processing Record 18 of Set 10 | jatiroto
# Processing Record 19 of Set 10 | ambilobe
# Processing Record 20 of Set 10 | maceio
# Processing Record 21 of Set 10 | cap-aux-meules
# Processing Record 22 of Set 10 | udgir
# Processing Record 23 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 24 of Set 10 | poum
# Processing Record 25 of Set 10 | mbanza-ngungu
# Processing Record 26 of Set 10 | porto novo
# Processing Record 27 of Set 10 | korla
# Processing Record 28 of Set 10 | borlange
# City not found. Skipping...
# Processing Record 29 of Set 10 | ratnagiri
# Processing Record 30 of Set 10 | klyuchi
# Processing Record 31 of Set 10 | tuensang
# Processing Record 32 of Set 10 | macamic
# Processing Record 33 of Set 10 | buin
# Processing Record 34 of Set 10 | la ligua
# Processing Record 35 of Set 10 | soria
# Processing Record 36 of Set 10 | calama
# Processing Record 37 of Set 10 | tera
# Processing Record 38 of Set 10 | deputatskiy
# Processing Record 39 of Set 10 | muslyumovo
# Processing Record 40 of Set 10 | bonthe
# Processing Record 41 of Set 10 | kopyevo
# City not found. Skipping...
# Processing Record 42 of Set 10 | lieksa
# Processing Record 43 of Set 10 | tikrit
# Processing Record 44 of Set 10 | mahibadhoo
# Processing Record 45 of Set 10 | teahupoo
# Processing Record 46 of Set 10 | vestmanna
# Processing Record 47 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 48 of Set 10 | monopoli
# Processing Record 49 of Set 10 | pontianak
# Processing Record 50 of Set 10 | bantry
# Processing Record 1 of Set 11 | chebsara
# Processing Record 2 of Set 11 | atherton
# Processing Record 3 of Set 11 | koutsouras
# Processing Record 4 of Set 11 | pringsewu
# Processing Record 5 of Set 11 | soe
# Processing Record 6 of Set 11 | marathopolis
# City not found. Skipping...
# Processing Record 7 of Set 11 | anadyr
# Processing Record 8 of Set 11 | laguna
# Processing Record 9 of Set 11 | yar-sale
# Processing Record 10 of Set 11 | bouna
# Processing Record 11 of Set 11 | gedo
# Processing Record 12 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 13 of Set 11 | moerai
# Processing Record 14 of Set 11 | ancud
# Processing Record 15 of Set 11 | waingapu
# Processing Record 16 of Set 11 | henties bay
# Processing Record 17 of Set 11 | korcula
# Processing Record 18 of Set 11 | angoche
# Processing Record 19 of Set 11 | rosarito
# Processing Record 20 of Set 11 | shar
# Processing Record 21 of Set 11 | abu samrah
# Processing Record 22 of Set 11 | synya
# Processing Record 23 of Set 11 | eureka
# Processing Record 24 of Set 11 | edd
# Processing Record 25 of Set 11 | kamina
# Processing Record 26 of Set 11 | villanueva
# Processing Record 27 of Set 11 | erenhot
# Processing Record 28 of Set 11 | sorochinsk
# Processing Record 29 of Set 11 | kloulklubed
# Processing Record 30 of Set 11 | zonguldak
# Processing Record 31 of Set 11 | maryville
# Processing Record 32 of Set 11 | tshikapa
# Processing Record 33 of Set 11 | gwanda
# Processing Record 34 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 11 | coolum beach
# Processing Record 36 of Set 11 | gamba
# Processing Record 37 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 11 | catuday
# Processing Record 39 of Set 11 | kaeo
# Processing Record 40 of Set 11 | machinga
# Processing Record 41 of Set 11 | surt
# Processing Record 42 of Set 11 | sa kaeo
# Processing Record 43 of Set 11 | cidreira
# Processing Record 44 of Set 11 | loralai
# Processing Record 45 of Set 11 | kemijarvi
# Processing Record 46 of Set 11 | grand gaube
# Processing Record 47 of Set 11 | sydney
# Processing Record 48 of Set 11 | ardmore
# Processing Record 49 of Set 11 | rushden
# Processing Record 50 of Set 11 | qunduz
# Processing Record 1 of Set 12 | finschhafen
# Processing Record 2 of Set 12 | shaunavon
# Processing Record 3 of Set 12 | adoni
# Processing Record 4 of Set 12 | cuyo
# Processing Record 5 of Set 12 | ixtapa
# Processing Record 6 of Set 12 | rach gia
# Processing Record 7 of Set 12 | mahajanga
# Processing Record 8 of Set 12 | sault sainte marie
# Processing Record 9 of Set 12 | rawah
# Processing Record 10 of Set 12 | yulara
# Processing Record 11 of Set 12 | suntar
# Processing Record 12 of Set 12 | aykhal
# Processing Record 13 of Set 12 | senmonorom
# City not found. Skipping...
# Processing Record 14 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 15 of Set 12 | pitelino
# Processing Record 16 of Set 12 | inuvik
# Processing Record 17 of Set 12 | khasan
# Processing Record 18 of Set 12 | tome
# Processing Record 19 of Set 12 | kuytun
# Processing Record 20 of Set 12 | kosh-agach
# Processing Record 21 of Set 12 | birao
# Processing Record 22 of Set 12 | atar
# Processing Record 23 of Set 12 | okhotsk
# Processing Record 24 of Set 12 | coromandel
# Processing Record 25 of Set 12 | ossora
# Processing Record 26 of Set 12 | sept-iles
# Processing Record 27 of Set 12 | awjilah
# Processing Record 28 of Set 12 | alta floresta
# Processing Record 29 of Set 12 | ardistan
# City not found. Skipping...
# Processing Record 30 of Set 12 | alofi
# Processing Record 31 of Set 12 | ahuimanu
# Processing Record 32 of Set 12 | zavodskoy
# Processing Record 33 of Set 12 | kirensk
# Processing Record 34 of Set 12 | tecoanapa
# Processing Record 35 of Set 12 | margate
# Processing Record 36 of Set 12 | singaraja
# Processing Record 37 of Set 12 | bereda
# Processing Record 38 of Set 12 | aleksandrovka
# Processing Record 39 of Set 12 | aitape
# Processing Record 40 of Set 12 | dhuwaran
# Processing Record 41 of Set 12 | vila velha
# Processing Record 42 of Set 12 | carbonia
# Processing Record 43 of Set 12 | regina
# Processing Record 44 of Set 12 | bathsheba
# Processing Record 45 of Set 12 | sao felix do xingu
# Processing Record 46 of Set 12 | storslett
# Processing Record 47 of Set 12 | kerki
# City not found. Skipping...
# Processing Record 48 of Set 12 | tall kayf
# Processing Record 49 of Set 12 | pyapon
# Processing Record 50 of Set 12 | merauke
# Processing Record 1 of Set 13 | antofagasta
# Processing Record 2 of Set 13 | san juan
# Processing Record 3 of Set 13 | tokur
# Processing Record 4 of Set 13 | bira
# Processing Record 5 of Set 13 | riberalta
# Processing Record 6 of Set 13 | hobyo
# Processing Record 7 of Set 13 | hasaki
# Processing Record 8 of Set 13 | anju
# Processing Record 9 of Set 13 | kupang
# Processing Record 10 of Set 13 | fengzhen
# Processing Record 11 of Set 13 | severo-kurilsk
# Processing Record 12 of Set 13 | portland
# Processing Record 13 of Set 13 | bad liebenwerda
# Processing Record 14 of Set 13 | elban
# Processing Record 15 of Set 13 | shimoni
# Processing Record 16 of Set 13 | getulio vargas
# Processing Record 17 of Set 13 | galiwinku
# City not found. Skipping...
# Processing Record 18 of Set 13 | arlit
# Processing Record 19 of Set 13 | khromtau
# Processing Record 20 of Set 13 | kristiansund
# Processing Record 21 of Set 13 | malmesbury
# Processing Record 22 of Set 13 | ipora
# Processing Record 23 of Set 13 | addi ugri
# City not found. Skipping...
# Processing Record 24 of Set 13 | walvis bay
# Processing Record 25 of Set 13 | nouadhibou
# Processing Record 26 of Set 13 | mullaitivu
# City not found. Skipping...
# Processing Record 27 of Set 13 | marystown
# Processing Record 28 of Set 13 | paita
# Processing Record 29 of Set 13 | harper
# Processing Record 30 of Set 13 | great yarmouth
# Processing Record 31 of Set 13 | vestmannaeyjar
# Processing Record 32 of Set 13 | okakarara
# Processing Record 33 of Set 13 | innisfail
# Processing Record 34 of Set 13 | caravelas
# Processing Record 35 of Set 13 | skibbereen
# Processing Record 36 of Set 13 | chagda
# City not found. Skipping...
# Processing Record 37 of Set 13 | kaffrine
# Processing Record 38 of Set 13 | koumac
# Processing Record 39 of Set 13 | shenjiamen
# Processing Record 40 of Set 13 | san jose
# Processing Record 41 of Set 13 | omboue
# Processing Record 42 of Set 13 | kure
# Processing Record 43 of Set 13 | ugoofaaru
# Processing Record 44 of Set 13 | sinnamary
# Processing Record 45 of Set 13 | banyo
# Processing Record 46 of Set 13 | kulhudhuffushi
# Processing Record 47 of Set 13 | san joaquin
# Processing Record 48 of Set 13 | mecca
# Processing Record 49 of Set 13 | kokstad
# Processing Record 50 of Set 13 | macau
# Processing Record 1 of Set 14 | igarka
# Processing Record 2 of Set 14 | kismayo
# Processing Record 3 of Set 14 | porto seguro
# Processing Record 4 of Set 14 | barra da estiva
# Processing Record 5 of Set 14 | daule
# Processing Record 6 of Set 14 | yarada
# Processing Record 7 of Set 14 | katangli
# Processing Record 8 of Set 14 | rongcheng
# Processing Record 9 of Set 14 | bidor
# Processing Record 10 of Set 14 | zhigansk
# Processing Record 11 of Set 14 | pangnirtung
# Processing Record 12 of Set 14 | sao francisco de paula
# Processing Record 13 of Set 14 | necochea
# Processing Record 14 of Set 14 | marche-en-famenne
# Processing Record 15 of Set 14 | bilma
# Processing Record 16 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 17 of Set 14 | chadan
# Processing Record 18 of Set 14 | puerto escondido
# Processing Record 19 of Set 14 | dongying
# Processing Record 20 of Set 14 | tinskoy
# Processing Record 21 of Set 14 | ruteng
# Processing Record 22 of Set 14 | golden
# Processing Record 23 of Set 14 | mweka
# Processing Record 24 of Set 14 | samarinda
# Processing Record 25 of Set 14 | dubenskiy
# City not found. Skipping...
# Processing Record 26 of Set 14 | tottori
# Processing Record 27 of Set 14 | ocean springs
# Processing Record 28 of Set 14 | gao
# Processing Record 29 of Set 14 | tortoli
# Processing Record 30 of Set 14 | bangassou
# Processing Record 31 of Set 14 | shetpe
# Processing Record 32 of Set 14 | babanka
# Processing Record 33 of Set 14 | vagur
# Processing Record 34 of Set 14 | redcar
# Processing Record 35 of Set 14 | soyo
# Processing Record 36 of Set 14 | picota
# Processing Record 37 of Set 14 | talawdi
# City not found. Skipping...
# Processing Record 38 of Set 14 | luwingu
# Processing Record 39 of Set 14 | sannicandro di bari
# Processing Record 40 of Set 14 | semey
# Processing Record 41 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 42 of Set 14 | yumen
# Processing Record 43 of Set 14 | middle island
# Processing Record 44 of Set 14 | santa fe
# Processing Record 45 of Set 14 | chunskiy
# Processing Record 46 of Set 14 | aktash
# Processing Record 47 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 48 of Set 14 | sur
# Processing Record 49 of Set 14 | muswellbrook
# Processing Record 50 of Set 14 | pemangkat
# Processing Record 1 of Set 15 | malakal
# Processing Record 2 of Set 15 | komsomolskiy
# Processing Record 3 of Set 15 | rafaela
# Processing Record 4 of Set 15 | the valley
# Processing Record 5 of Set 15 | tazmalt
# Processing Record 6 of Set 15 | vila
# Processing Record 7 of Set 15 | nadvoitsy
# Processing Record 8 of Set 15 | cartagena
# Processing Record 9 of Set 15 | palmer
# Processing Record 10 of Set 15 | zhangye
# Processing Record 11 of Set 15 | kinlochleven
# Processing Record 12 of Set 15 | troitskoye
# Processing Record 13 of Set 15 | lamu
# Processing Record 14 of Set 15 | arman
# Processing Record 15 of Set 15 | skjervoy
# Processing Record 16 of Set 15 | onega
# Processing Record 17 of Set 15 | strelka
# Processing Record 18 of Set 15 | invermere
# Processing Record 19 of Set 15 | bokspits
# City not found. Skipping...
# Processing Record 20 of Set 15 | pavino
# Processing Record 21 of Set 15 | kushiro
# Processing Record 22 of Set 15 | sabla
# Processing Record 23 of Set 15 | mazagao
# Processing Record 24 of Set 15 | wehr
# Processing Record 25 of Set 15 | auch
# Processing Record 26 of Set 15 | babanusah
# City not found. Skipping...
# Processing Record 27 of Set 15 | oktyabrskiy
# Processing Record 28 of Set 15 | kawalu
# Processing Record 29 of Set 15 | neuquen
# Processing Record 30 of Set 15 | caceres
# Processing Record 31 of Set 15 | benguela
# Processing Record 32 of Set 15 | nantucket
# Processing Record 33 of Set 15 | kizukuri
# Processing Record 34 of Set 15 | trapani
# Processing Record 35 of Set 15 | dunayivtsi
# City not found. Skipping...
# Processing Record 36 of Set 15 | poya
# Processing Record 37 of Set 15 | hami
# Processing Record 38 of Set 15 | santa marta
# Processing Record 39 of Set 15 | ati
# Processing Record 40 of Set 15 | canon city
# Processing Record 41 of Set 15 | gangotri
# City not found. Skipping...
# Processing Record 42 of Set 15 | sabha
# Processing Record 43 of Set 15 | batticaloa
# Processing Record 44 of Set 15 | montalvo
# Processing Record 45 of Set 15 | mikhaylovskoye
# Processing Record 46 of Set 15 | lata
# Processing Record 47 of Set 15 | tari
# Processing Record 48 of Set 15 | weymouth
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
weather_data_df = pd.DataFrame(city_data)

weather_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Vardo      NO  70.3705   31.1107     53.58        94         100
# 1  Inhambane      MZ -23.8650   35.3833     66.76        67           0
# 2    Mataura      NZ -46.1927  168.8643     37.47        99         100
# 3    Kavieng      PG  -2.5744  150.7967     81.32        79         100
# 4  Nishihara      JP  26.1842  127.7558     82.45        91          40
# 5   Cherskiy      RU  68.7500  161.3000     47.52        55         100
# 6     Bethel      US  41.3712  -73.4140     87.89        55          75
# 7     Dikson      RU  73.5069   80.5464     41.13        79          18
# 8      Buala      SB  -8.1450  159.5921     79.77        76         100
# 9        Leh      IN  34.1667   77.5833     58.14        67          99
#
#    Wind Speed Weather Description                 Date
# 0        2.30       moderate rain  2022-07-14 20:41:40
# 1        6.76           clear sky  2022-07-14 20:41:41
# 2        2.80          light rain  2022-07-14 20:41:41
# 3       14.76          light rain  2022-07-14 20:41:41
# 4        9.22    scattered clouds  2022-07-14 20:41:42
# 5        1.03     overcast clouds  2022-07-14 20:41:42
# 6        3.44       broken clouds  2022-07-14 20:41:42
# 7       10.45          few clouds  2022-07-14 20:41:43
# 8        3.83     overcast clouds  2022-07-14 20:41:43
# 9        6.29     overcast clouds  2022-07-14 20:40:29

# %%
#This step was necessary to match the dataframe image from the challenge directions. Date was added in a previous step by accident, and corrected here.

del weather_data_df['Date']

weather_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Vardo      NO  70.3705   31.1107     53.58        94         100
# 1  Inhambane      MZ -23.8650   35.3833     66.76        67           0
# 2    Mataura      NZ -46.1927  168.8643     37.47        99         100
# 3    Kavieng      PG  -2.5744  150.7967     81.32        79         100
# 4  Nishihara      JP  26.1842  127.7558     82.45        91          40
#
#    Wind Speed Weather Description
# 0        2.30       moderate rain
# 1        6.76           clear sky
# 2        2.80          light rain
# 3       14.76          light rain
# 4        9.22    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
weather_data_df.to_csv(output_data_file, index_label="City_ID")
